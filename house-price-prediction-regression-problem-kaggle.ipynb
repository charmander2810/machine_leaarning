# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
house_train=pd.read_csv("train.csv")
house_test=pd.read_csv("test.csv")
house_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
x=house_train

# %%
x1=house_test

# %%
x1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
y=house_train["SalePrice"]

# %%
x1["SalePrice"]="NaN"

# %%
house_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
x1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
#fill the above column into median value 
for label,content in house_train.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            house_train[label]=content.fillna(content.median())
            #now all the integer and float values are filled

# %% [markdown]
# x_train=house_train.drop("SalePrice",axis=1)
# y_train=house_train["SalePrice"]
# x_test=house_test.copy()

# %%
#fill the above column into median value 
for label,content in house_test.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            house_test[label]=content.fillna(content.median())
            #now all the integer and float values are filled

# %%
# fill the missing value for string using scikit learn method
# fill the missing values with scikit-learn
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# fill categorical values with 'missing' and 'numerical' value with mean
cat_imputer = SimpleImputer(strategy="constant", fill_value="missing")

#define columns
cat_features = ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice']

#create an imputer (something that fills missing date)
imputer = ColumnTransformer([
    ("cat_imputer",cat_imputer,cat_features)
])


#transform the data
filled_x=imputer.fit_transform(x)
filled_x
# Out:
# array([[1, 60, 'RL', ..., 'WD', 'Normal', 208500],
#        [2, 20, 'RL', ..., 'WD', 'Normal', 181500],
#        [3, 60, 'RL', ..., 'WD', 'Normal', 223500],
#        ...,
#        [1458, 70, 'RL', ..., 'WD', 'Normal', 266500],
#        [1459, 20, 'RL', ..., 'WD', 'Normal', 142125],
#        [1460, 20, 'RL', ..., 'WD', 'Normal', 147500]], dtype=object)

# %%
# fill the missing value for string using scikit learn method
# fill the missing values with scikit-learn
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# fill categorical values with 'missing' and 'numerical' value with mean
cat_imputer = SimpleImputer(strategy="constant", fill_value="missing")

#define columns
cat_features = ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice']

#create an imputer (something that fills missing date)
imputer = ColumnTransformer([
    ("cat_imputer",cat_imputer,cat_features)
])


#transform the data
filled_x1=imputer.fit_transform(x1)
filled_x1
# Out:
# array([[1461, 20, 'RH', ..., 'WD', 'Normal', 'NaN'],
#        [1462, 20, 'RL', ..., 'WD', 'Normal', 'NaN'],
#        [1463, 60, 'RL', ..., 'WD', 'Normal', 'NaN'],
#        ...,
#        [2917, 20, 'RL', ..., 'WD', 'Abnorml', 'NaN'],
#        [2918, 85, 'RL', ..., 'WD', 'Normal', 'NaN'],
#        [2919, 60, 'RL', ..., 'WD', 'Normal', 'NaN']], dtype=object)

# %%
x.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
x1.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#this dataframe is a fully filled object datatype
house_filled = pd.DataFrame(filled_x,columns=['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice'])
house_filled.head()
# Out:
#   Id MSSubClass MSZoning LotFrontage LotArea Street    Alley LotShape  \
# 0  1         60       RL        65.0    8450   Pave  missing      Reg
# 1  2         20       RL        80.0    9600   Pave  missing      Reg
# 2  3         60       RL        68.0   11250   Pave  missing      IR1
# 3  4         70       RL        60.0    9550   Pave  missing      IR1
# 4  5         60       RL        84.0   14260   Pave  missing      IR1
#
#   LandContour Utilities  ... PoolArea   PoolQC    Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0  missing  missing     missing       0
# 1         Lvl    AllPub  ...        0  missing  missing     missing       0
# 2         Lvl    AllPub  ...        0  missing  missing     missing       0
# 3         Lvl    AllPub  ...        0  missing  missing     missing       0
# 4         Lvl    AllPub  ...        0  missing  missing     missing       0
#
#   MoSold YrSold SaleType SaleCondition SalePrice
# ...

# %%
#this dataframe is a fully filled object datatype
house_filled1= pd.DataFrame(filled_x1,columns=['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice'])
house_filled1.head()
# Out:
#      Id MSSubClass MSZoning LotFrontage LotArea Street    Alley LotShape  \
# 0  1461         20       RH        80.0   11622   Pave  missing      Reg
# 1  1462         20       RL        81.0   14267   Pave  missing      IR1
# 2  1463         60       RL        74.0   13830   Pave  missing      IR1
# 3  1464         60       RL        78.0    9978   Pave  missing      IR1
# 4  1465        120       RL        43.0    5005   Pave  missing      IR1
#
#   LandContour Utilities  ... PoolArea   PoolQC    Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0  missing    MnPrv     missing       0
# 1         Lvl    AllPub  ...        0  missing  missing        Gar2   12500
# 2         Lvl    AllPub  ...        0  missing    MnPrv     missing       0
# 3         Lvl    AllPub  ...        0  missing  missing     missing       0
# 4         HLS    AllPub  ...        0  missing  missing     missing       0
#
#   MoSold YrSold SaleType SaleCondition SalePrice
# ...

# %%
final_x=pd.concat([house_filled,house_filled1],axis=0)

# %%
final_x
# Out:
#         Id MSSubClass MSZoning LotFrontage LotArea Street    Alley LotShape  \
# 0        1         60       RL        65.0    8450   Pave  missing      Reg
# 1        2         20       RL        80.0    9600   Pave  missing      Reg
# 2        3         60       RL        68.0   11250   Pave  missing      IR1
# 3        4         70       RL        60.0    9550   Pave  missing      IR1
# 4        5         60       RL        84.0   14260   Pave  missing      IR1
# ...    ...        ...      ...         ...     ...    ...      ...      ...
# 1454  2915        160       RM        21.0    1936   Pave  missing      Reg
# 1455  2916        160       RM        21.0    1894   Pave  missing      Reg
# 1456  2917         20       RL       160.0   20000   Pave  missing      Reg
# 1457  2918         85       RL        62.0   10441   Pave  missing      Reg
# 1458  2919         60       RL        74.0    9627   Pave  missing      Reg
#
# ...

# %%
df_train=final_x.iloc[:1460,:]
df_test=final_x.iloc[1460:,:]

# %%
df_test=df_test.drop(["SalePrice"],axis=1)

# %%
y=df_train["SalePrice"]

# %%
df_train=df_train.drop(["SalePrice"],axis=1)

# %%
df_train=df_train.drop("Id",axis=1)

# %%
df_test=df_test.drop("Id",axis=1)

# %%
df_train.shape
# Out:
# (1460, 79)

# %%
df_test
# Out:
#      MSSubClass MSZoning LotFrontage LotArea Street    Alley LotShape  \
# 0            20       RH        80.0   11622   Pave  missing      Reg
# 1            20       RL        81.0   14267   Pave  missing      IR1
# 2            60       RL        74.0   13830   Pave  missing      IR1
# 3            60       RL        78.0    9978   Pave  missing      IR1
# 4           120       RL        43.0    5005   Pave  missing      IR1
# ...         ...      ...         ...     ...    ...      ...      ...
# 1454        160       RM        21.0    1936   Pave  missing      Reg
# 1455        160       RM        21.0    1894   Pave  missing      Reg
# 1456         20       RL       160.0   20000   Pave  missing      Reg
# 1457         85       RL        62.0   10441   Pave  missing      Reg
# 1458         60       RL        74.0    9627   Pave  missing      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea   PoolQC  \
# ...

# %% [markdown]
# #lets try our data into number(means converting he words to number)
#
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.compose import ColumnTransformer
#
# categorical_features=["MSZoning",
# "Street",
# "Alley",
# "LotShape",
# "LandContour",
# "Utilities",
# "LotConfig",
# "LandSlope",
# "Neighborhood",
# "Condition1",
# "Condition2",
# "BldgType",
# "HouseStyle",
# "RoofStyle",
# "RoofMatl",
# "Exterior1st",
# "Exterior2nd",
# "MasVnrType",
# "ExterQual",
# "ExterCond",
# "Foundation",
# "BsmtQual",
# "BsmtCond",
# "BsmtExposure",
# "BsmtFinType1",
# "BsmtFinType2",
# "Heating",
# "HeatingQC",
# "CentralAir",
# "Electrical",
# "KitchenQual",
# "Functional",
# "FireplaceQu",
# "GarageType",
# "GarageFinish",
# "GarageQual",
# "GarageCond",
# "PavedDrive",
# "PoolQC",
# "Fence",
# "MiscFeature",
# "SaleType",
# "SaleCondition"]
# one_hot=OneHotEncoder()
# transformer=ColumnTransformer([("one_hot",
#                                 one_hot,
#                                 categorical_features)],
#                              remainder="passthrough")
# transformed_x=transformer.fit_transform(df_train)
# transformed_x

# %% [markdown]
# #lets try our data into number(means converting he words to number)
#
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.compose import ColumnTransformer
#
# categorical_features=["MSZoning",
# "Street",
# "Alley",
# "LotShape",
# "LandContour",
# "Utilities",
# "LotConfig",
# "LandSlope",
# "Neighborhood",
# "Condition1",
# "Condition2",
# "BldgType",
# "HouseStyle",
# "RoofStyle",
# "RoofMatl",
# "Exterior1st",
# "Exterior2nd",
# "MasVnrType",
# "ExterQual",
# "ExterCond",
# "Foundation",
# "BsmtQual",
# "BsmtCond",
# "BsmtExposure",
# "BsmtFinType1",
# "BsmtFinType2",
# "Heating",
# "HeatingQC",
# "CentralAir",
# "Electrical",
# "KitchenQual",
# "Functional",
# "FireplaceQu",
# "GarageType",
# "GarageFinish",
# "GarageQual",
# "GarageCond",
# "PavedDrive",
# "PoolQC",
# "Fence",
# "MiscFeature",
# "SaleType",
# "SaleCondition"]
# one_hot=OneHotEncoder()
# transformer=ColumnTransformer([("one_hot",
#                                 one_hot,
#                                 categorical_features)],
#                              remainder="passthrough")
# transformed_x1=transformer.fit_transform(df_test)
# transformed_x1

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
def Encoder(df):
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
df_trains = Encoder(df_train)

# %%
df_trains
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0              5         3           36      327       1      2         3
# 1              0         3           51      498       1      2         3
# 2              5         3           39      702       1      2         0
# 3              6         3           31      489       1      2         0
# 4              5         3           55      925       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1455           5         3           33      267       1      2         3
# 1456           0         3           56      866       1      2         3
# 1457           6         3           37      415       1      2         3
# 1458           0         3           39      505       1      2         3
# 1459           0         3           46      532       1      2         3
#
#       LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
df_tests = Encoder(df_test)

# %%
df_tests
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0              0         2           56      777       1      2         3
# 1              0         3           57      964       1      2         0
# 2              5         3           50      947       1      2         0
# 3              5         3           54      587       1      2         0
# 4             11         3           19      118       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1454          13         4            0       19       1      2         3
# 1455          13         4            0       17       1      2         3
# 1456           0         3          112     1069       1      2         3
# 1457           9         3           38      647       1      2         3
# 1458           5         3           50      536       1      2         3
#
#       LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
df_trains.shape
# Out:
# (1460, 79)

# %%
df_tests.shape
# Out:
# (1459, 79)

# %%
#model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(df_trains,
                                               y,
                                               test_size=0.1)
model=LinearRegression().fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.6532352567495252

# %%
final_solution=model.predict(df_tests)

# %%
final_solution
# Out:
# array([ 60121.90958327, 109897.4518769 , 117251.70568667, ...,
#        120674.14498152,  72453.64897526, 191586.5713412 ])

# %%
import pickle
filename='finalized_houseofme_model.pk1'
pickle.dump(model,open(filename,'wb'))

# %%
y_pred=model.predict(df_tests)

# %%
submission = pd.DataFrame({
        "Id": range(1461, 2920),
        "SalePrice": y_pred
    })

# %%
submission
# Out:
#         Id      SalePrice
# 0     1461   60121.909583
# 1     1462  109897.451877
# 2     1463  117251.705687
# 3     1464  127305.788512
# 4     1465  129409.220791
# ...    ...            ...
# 1454  2915   14637.427201
# 1455  2916    1203.294788
# 1456  2917  120674.144982
# 1457  2918   72453.648975
# 1458  2919  191586.571341
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('submission.csv', index = False)
